# %%
import mercury as mr
import numpy as np
from matplotlib import pyplot as plt
 
app = mr.App(title="Slides demo 📝", description="Wouldn't it be amazing to recompute slides during the show?", show_code = True)

# %% [markdown]
# ## Go to https://github.com and sign up for an account:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Go to Moodle and click on Project 1:
# ![image.png](attachment:image.png)
#
# ## Then click the link:
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## If asked to choose an email, choose yours!
#
# ## Click to accept the assignment
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Click to open a Git Codespace
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Now let's talk about codespaces!

# %% [markdown]
# ## In the codespace, open the README.md and add your name
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Click the little blue circle, add a commit message, commit
# ![image.png](attachment:image.png)
# ## And sync
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Now let's talk about Github!

# %% [markdown]
# ## Open project1.ipynb and click choose a kernel
# ![image.png](attachment:image.png)
#
# ## Choose a python kernel to install
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Once it has installed, choose it
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Now let's talk about Jupyter notebooks!

# %% [markdown]
# ## And now let's talk about spacy NLP!
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Now let's recap what you need to do for project 1
